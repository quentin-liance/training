# %% [markdown]
# # Notebook de Test
#
# Ce notebook sert de template de démarrage pour le projet training.

# %%
# Import des bibliothèques de base
import sys
from pathlib import Path

print(f"Python version: {sys.version}")
print(f"Working directory: {Path.cwd()}")
# Out:
# Python version: 3.12.12 (main, Jan 13 2026, 03:11:57) [GCC 14.2.0]
# Working directory: /workspace/notebooks

# %% [markdown]
# ## Test d'import du module principal

# %%
import src

# Tester la fonction main
src.main()
# Out:
# Hello from training project!

# %% [markdown]
# ## Expérimentations
#
# Espace pour vos tests et expérimentations.

# %%
# Votre code ici
print("Prêt à expérimenter !")
# Out:
# Prêt à expérimenter !
